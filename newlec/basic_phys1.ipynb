# %%
using Plots

# %%
g = 9.8
ts = range(0,5,step=1/30)
ys = 1/2 * g.*ts.^2
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 5 # 質点の半径
anim = Animation()
for i in 1:length(ts)
    t = round(ts[i],digits=3)
    plt=plot(0 .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-50,50),ylims=(-10,100),yaxis=:flip,label="t = $(t)",ylabel="y",linewidth=2,linecolor=:blue)
    frame(anim,plt)
end
gif(anim,"freefall.gif",fps=30)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefall.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefall.gif")

# %%
g = 9.8
ts = range(0,5,step=1/2)
ys = 1/2 * g.*ts.^2
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 5 # 質点の半径
anim = Animation()
plt=plot()
for i in 1:length(ts)
    t = round(ts[i],digits=3)
    plt=plot!(0 .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-50,50),ylims=(-10,100),yaxis=:flip,label="",ylabel="y",linewidth=2,linecolor=:blue)
    frame(anim,plt)
end
gif(anim,"freefallstrobo.mp4",fps=2)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefallstrobo.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefallstrobo.mp4")

# %%
g = 9.8
ts = range(0,1,step=1/30)
ys = 1/2 * g.*ts.^2
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 0.2 # 質点の半径
anim = Animation()
for i in 1:length(ts)
    t = round(ts[i],digits=3)
    plt=plot(0 .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-1,1),ylims=(-0.3,3),yaxis=:flip,label="",ylabel="y",linewidth=2,linecolor=:blue)
    frame(anim,plt)
end
gif(anim,"freefall.mp4",fps=30)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefall.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefall.mp4")

# %%
g = 9.8
ts = range(0,1,step=1/10)
ys = 1/2 * g.*ts.^2
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 0.2 # 質点の半径
anim = Animation()
plt=plot()
for i in 1:length(ts)
    t = round(ts[i],digits=3)
    plt=plot!(0 .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-1,1),ylims=(-0.3,3),yaxis=:flip,label="",ylabel="y",linewidth=2,linecolor=:blue)
    frame(anim,plt)
end
gif(anim,"freefallstrobo.mp4",fps=10)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefallstrobo.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/newlec/freefallstrobo.mp4")
