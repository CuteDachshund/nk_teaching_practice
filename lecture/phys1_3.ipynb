# %%
include("phys1func.jl")
# Out:
# gen_circularanim (generic function with 2 methods)

# %%
data1 = calc_circular(3.0,50);
data2 = calc_circular(3.0,70);

# %%
gen_circularanim(data1,trj=true,ang=true,strobe=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_oZwD4zMPgJ.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_oZwD4zMPgJ.gif")

# %%
gen_circularanim(data2,trj=true,ang=true,strobe=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_q96rcFKzeh.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_q96rcFKzeh.gif")

# %%
gen_circularanim(data1,data2,ang=true,strobe=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_cdYdIFIXgn.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_cdYdIFIXgn.gif")

# %% [markdown]
# 二つの円運動の角速度は明らかに等しいが、半径が違うため速度がことなることがわかる。
