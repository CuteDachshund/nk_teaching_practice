# %%
include("phys1func2.jl")
# Out:
# gen_circularanim_mp4 (generic function with 2 methods)

# %%
data1 = calc_circular(2π,50)
data2 = calc_circular(π,50)
data3 = calc_circular(4π,50)
# Out:
# ([0.0, 0.0, 0.1, 0.2, 0.2, 0.2, 0.3, 0.4, 0.4, 0.4  …  0.6, 0.6, 0.6, 0.7, 0.8, 0.8, 0.8, 0.9, 1.0, 1.0], [50.0, 40.45084971874737, 15.450849718747373, -15.450849718747367, -40.450849718747364, -50.0, -40.45084971874737, -15.450849718747378, 15.450849718747362, 40.450849718747364  …  40.45084971874736, 15.450849718747387, -15.450849718747357, -40.450849718747364, -50.0, -40.450849718747385, -15.450849718747392, 15.45084971874735, 40.45084971874736, 50.0], [0.0, 29.389262614623657, 47.552825814757675, 47.55282581475768, 29.38926261462366, 6.123233995736766e-15, -29.38926261462365, -47.552825814757675, -47.55282581475768, -29.389262614623668  …  29.38926261462368, 47.552825814757675, 47.55282581475768, 29.389262614623668, 1.8369701987210297e-14, -29.38926261462364, -47.55282581475767, -47.55282581475769, -29.389262614623675, -2.4492935982947064e-14], [-0.0, -369.31636609809135, -597.5664329483111, -597.5664329483112, -369.3163660980914, -7.694682774887159e-14, 369.31636609809124, 597.5
# ...

# %%
gen_circularanim_mp4(data2)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4")

# %%
gen_circularanim_mp4(data1)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4")

# %%
gen_circularanim_mp4(data3)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4")
