# %%
include("phys1func.jl")
data1 = calc_circular(1.0,50)
data2 = calc_circular(2.0,50)
gen_circularanim(data1,trj=true,ang=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_2XIPMZaHsR.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_2XIPMZaHsR.gif")

# %%
gen_circularanim(data2,trj=true,ang=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_OpQLWDm3OJ.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_OpQLWDm3OJ.gif")

# %%
gen_circularanim_mp4(data2,trj=true,ang=true)
# Out:
# ┌ Info: Saved animation to /Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/Users/busseirironibarakidaigaku/nk_teaching_practice/lecture/anim.mp4")
