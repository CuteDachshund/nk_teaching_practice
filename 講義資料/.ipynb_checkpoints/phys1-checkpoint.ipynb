# %%
using Plots
using Flux

function calc_circular(om,R) # 円運動の軌道を計算する
    T = 2*π/om
    fx(t) = R*cos(om*t) # x,y成分の軌道の時間の式 
    fy(t) = R*sin(om*t)
    vx(t) = fx'(t) #速度の式を軌道の式からつくる
    vy(t) = fy'(t)
    ax(t) = vx'(t)
    ay(t) = vy'(t)
    ts = range(0,T,step=1/20) # 時間
    xs = fx.(ts)
    ys = fy.(ts)
    xvs= vx.(ts)
    yvs= vy.(ts) # 軌道・速度の時系列データを計算
    xas= ax.(ts)
    yas= ay.(ts) # 軌道・速度の時系列データを計算
    ts=round.(ts,digits=1) # 時間配列を表示に適した桁に修正
    return ts,xs,ys,xvs,yvs,xas,yas
end

function gen_circularanim(data1;xvel=false,yvel=false,trj=false,ang=false,vel=false,accs=false) # 円運動の動画を作る
    ts = data1[1]
    xs = data1[2]
    ys = data1[3]
    xvs=data1[4]
    yvs=data1[5]
    xas=data1[6]
    yas=data1[7]
    R = xs[1]
    theta = range(0,2π,step=0.01)#　質点描画
    r = 5 # 質点の半径
    anim = Animation()
    for i in 1:length(ts)
        plt=plot(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-100,100),ylims=(-100,100),label="",xlabel="x",ylabel="y",linecolor=:blue) # 質点のプロット
        if trj==true
            plt=plot!(xs[1:i],ys[1:i],label="t=$(ts[i])",legend = :bottomleft,foreground_color_legend = :white,alpha=0.2) # 軌道のプロット
        end
        if vel==true
            plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="v") # 速度のプロット
        end
        if xvel==true
            plt=plot!([xs[i],xs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="vy") # 速度のx成分のプロット
        end
        if yvel==true
            plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]], arrow = arrow(),label="vx") # 速度のy成分のプロット
        end
        if ang==true
            plt=plot!([0,xs[i]],[0,ys[i]],label="",linecolor=:blue,alpha=0.2) # 回転中心と質点を結ぶ直線
            plt=plot!([0,R],[0,0],label="",linecolor=:blue ,alpha=0.2) # 回転中心と質点を結ぶ直線
        end
        if accs==true
            plt=plot!([xs[i],xs[i]+xas[i]], [ys[i],ys[i]+yas[i]], arrow = arrow(),label="a")
        end
        frame(anim,plt)
    end
    gif(anim,fps=20)
end

function gen_circularsnap(data1,j;xvel=false,yvel=false,trj=false,ang=false,vel=false)
    ts = data1[1]
    xs = data1[2]
    ys = data1[3]
    xvs=data1[4]
    yvs=data1[5]
    R = xs[1]
    theta = range(0,2π,step=0.01)#　質点描画
    r = 5 # 質点の半径
    anim = Animation()
    i = j
    plt=plot(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-100,100),ylims=(-100,100),label="",xlabel="x",ylabel="y",linecolor=:blue) # 質点のプロット
    if trj==true
        plt=plot!(xs[1:i],ys[1:i],label="t=$(ts[i])",legend = :bottomleft,foreground_color_legend = :white,alpha=0.2) # 軌道のプロット
    end
    if vel==true
        plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="v") # 速度のプロット
    end
    if xvel==true
        plt=plot!([xs[i],xs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="vy") # 速度のx成分のプロット
    end
    if yvel==true
        plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]], arrow = arrow(),label="vx") # 速度のy成分のプロット
    end
    if ang==true
        plt=plot!([0,xs[i]],[0,ys[i]],label="",linecolor=:blue,alpha=0.2) # 回転中心と質点を結ぶ直線
        plt=plot!([0,R],[0,0],label="",linecolor=:blue ,alpha=0.2) # 回転中心と質点を結ぶ直線
    end
end

function gen_circularsnap!(data1,j;xvel=false,yvel=false,trj=false,ang=false,vel=false)
    ts = data1[1]
    xs = data1[2]
    ys = data1[3]
    xvs=data1[4]
    yvs=data1[5]
    R = xs[1]
    theta = range(0,2π,step=0.01)#　質点描画
    r = 5 # 質点の半径
    anim = Animation()
    i = j
    plt=plot!(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-100,100),ylims=(-100,100),label="",xlabel="x",ylabel="y",linecolor=:blue) # 質点のプロット
    if trj==true
        plt=plot!(xs[1:i],ys[1:i],label="t=$(ts[i])",legend = :bottomleft,foreground_color_legend = :white,alpha=0.2) # 軌道のプロット
    end
    if vel==true
        plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="v") # 速度のプロット
    end
    if xvel==true
        plt=plot!([xs[i],xs[i]], [ys[i],ys[i]+yvs[i]], arrow = arrow(),label="vy") # 速度のx成分のプロット
    end
    if yvel==true
        plt=plot!([xs[i],xs[i]+xvs[i]], [ys[i],ys[i]], arrow = arrow(),label="vx") # 速度のy成分のプロット
    end
    if ang==true
        plt=plot!([0,xs[i]],[0,ys[i]],label="",linecolor=:blue,alpha=0.2) # 回転中心と質点を結ぶ直線
        plt=plot!([0,R],[0,0],label="",linecolor=:blue ,alpha=0.2) # 回転中心と質点を結ぶ直線
    end
end
# Out:
# gen_circularsnap! (generic function with 1 method)

# %% [markdown]
# # 物理　第1編　第4章 第1節　等速円運動　(p64)

# %% [markdown]
# ## 角速度
#
# 物体が円周上を一定の速さで回ることを等速円運動と呼ぶ。
#
# 円運動する物体について、「単位時間あたりにどれくらいの角度を回るか？」という尺度が考えられる。
# これを角速度と呼ぶ。

# %%
data1 = calc_circular(1.0,50)
gen_circularanim(data1,trj=true,ang=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_WX4Dw1iZIZ.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_WX4Dw1iZIZ.gif")

# %%
data2 = calc_circular(2.0,50)
gen_circularanim(data2,trj=true,ang=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_cNM38T6bgV.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_cNM38T6bgV.gif")

# %% [markdown]
# 前者が一周する時間の半分の時間で後者は一周している。これは、後者の方が単位時間あたりに回る角度が大きい、すなわち後者のほうが「角速度が大きい」と理解することができる。
#
# 具体的に角速度を計算してみよう。
# 前者の円運動はだいたい$6.2$秒(厳密には$2\pi$秒)で一回転している。
# したがって、角速度$\omega$は
# $$\omega = 2\pi \mathrm{[rad]} / 2\pi\mathrm{[s]} = 1 \mathrm{[rad/s]}$$
# と計算できる。
# 一秒間に1[rad]だけ回転するということだ。
#
# 一般に、時間$t$の間に角度$\theta$だけ回転するような角速度$\omega$を
# $$\omega = \frac{\theta}{t}$$
# と定義する。
# 具体例から明らかなように、角速度の単位はラジアン毎秒([rad/s])である。

# %% [markdown]
# 次に、等速円運動の「速度」を考えたい。
# いま、半径$r\mathrm{[m]}$の円軌道を角速度$\omega\mathrm{[rad/s]}$で等速円運動している質点を考える。
# 運動開始から一秒間が経過したときの軌跡を見てみよう。

# %%
data1 = calc_circular(1.0,50)
gen_circularsnap(data1,20,trj=true,ang=true)

# %% [markdown]
# いま、一秒間だけ等速円運動しているので回転角度は$\omega\mathrm{[rad]}$である。
# 円の半径は$r\mathrm{[m]}$に設定していた。
#
# ここで弧度法の定義を思い出してみる。
# $\omega \mathrm{[rad]}$とは、半径$r$の円から長さ$r\omega$の弧を切り出す角度として定義したのだった。
#
# よって、図の弧の長さは$r\omega\mathrm{[m]}$であることがわかる。
# この弧は一秒間に質点が移動した道のりであるが、$\varDelta t$が限りなく小さい場合はこの間の変位の大きさとみなせる。
#
# まとめると、質点が
# 半径$r$の円を角速度$\omega$
# で等速円運動しているとき、その速度$v$は
# $$v=r \omega$$
#
# である。
#
# もし$\omega$が時とともに変化するならば、速度も時間とともに変化する一般的な(等速でない)円運動となる。

# %% [markdown]
# ここまでで、円運動の速度の大きさまではわかった。
# 次はその向きを考えたい。
#
# 速度の定義は
# $$\vec{v} = \frac{\varDelta \vec{r}}{\varDelta t} $$
# ただし$\varDelta t$は微小時間、であった。
#
# このベクトルをさきほどの軌跡に重ね合わせてみよう。

# %%
plot!([50,50*cos(1)], [0,50*sin(1)], arrow = arrow(),label="v")

# %% [markdown]
# これは$\varDelta t = 1 \mathrm{[s]}$の場合である。
# $\varDelta t$を限りなく小さくすると何が起こるかを考えてみよう。
# すると、その向きは

# %%
anim=Animation()
for n in 20:-1:1
    plt=gen_circularsnap(data1,n,trj=true,ang=true)
    plt=plot!([50,(50*cos(n/20)-50)/(n/20)+50], [0,(50*sin(n/20))/(n/20)], arrow = arrow(),label="v")
    frame(anim,plt)
end
gif(anim,fps=20)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_ePotWlMzk7.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_ePotWlMzk7.gif")

# %% [markdown]
# のように、円の接線方向に近づく。
# つまり、円運動の速度は円の接線方向であり、円の中心を向く方向に対して垂直である。
#
# 一般に、曲線的な運動の速度の方向は運動の経路の接線方向になる。

# %% [markdown]
# ## 周期と回転数
#
# 等速円運動において、一周するのにかかる時間を周期と呼ぶ。
#
# 半径$r\mathrm{[m]}$角速度$\omega \mathrm{[rad/s]}$の等速円運動の周期について考える。
# 一周とは回転角$2\pi\mathrm{[rad]}$に対応するのだから、一周にかかる時間$T$は
# $$T = \frac{2\pi}{\omega}$$
# と表せる。
# 一周に対応する角度の中に、一秒で回る角度が何個入っているかを考えれば、一周にかかる秒数がもとまる。
#
# 別の表現方法として、円周が$2\pi r$であり速度が$v(=r\omega)$であることから、
# $$T = \frac{2\pi r}{v}$$
# とも書ける。

# %% [markdown]
# 等速円運動の１秒あたりの回転の回数を回転数と呼ぶ。
# 単位にはヘルツ(Hz)を用いる。
# 回転数$n$と周期$T$の間には、
# $$n = \frac{1}{T}$$
# の関係がある。

# %% [markdown]
# ## 等速円運動の加速度
#
# 等速円運動では「速さ」は時間変化しないが「速度」は時間変化する。
# 速度は向きを含めた概念であること、円運動の速度はつねに円の接線方向を向くことを思い出せば、速度が時々刻々と変化することは明らかである。

# %%
gen_circularanim(data1,trj=true,vel=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_wlqX6hgFKZ.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_wlqX6hgFKZ.gif")

# %% [markdown]
# 速度に変化があるということは加速度が生じていることを意味する。
# この加速度$\vec{a}$について考えてみる。

# %% [markdown]
# 時刻$t=0$[s]から$t =1$[s]の間で速度がどのように変化するかを考えてみよう。

# %%
gen_circularsnap(data1,20,trj=true,ang=true,vel=true)
plot!(legend=:false)
gen_circularsnap!(data1,1,vel=true)
plot!()

# %% [markdown]
# 赤が$t=0\mathrm{[s]}$での速度であり、緑が$t=1\mathrm{[s]}$での速度である。
# このままだと分かりにくいので、二つのベクトルの始点をそろえてみる。

# %%
plot(aspectratio=1)
plot!([0,data1[4][20]], [0,data1[5][20]], arrow = arrow(),label="",linecolor=:green,alpha=0.2)
plot!([0,data1[4][1]], [0,data1[5][1]], arrow = arrow(),label="",linecolor=:red,alpha=0.2)
theta = range(0,2π,step=0.01)
plot!(50*cos.(theta),50*sin.(theta),linecolor=:blue,label="",alpha=0.2)
plot!([data1[4][1],data1[4][20]], [data1[5][1],data1[5][20]], arrow = arrow(),label="",linecolor=:black)

# %% [markdown]
# 加速度の定義
# $$\vec{a} = \frac{\varDelta \vec{v}}{\varDelta t}$$
# を思い出す。
#
# 図の黒い矢印が$\varDelta \vec{v}$に対応しており、いま$\varDelta t$として$1\mathrm{[s]}$を取っているので、このベクトルの長さが円運動の加速度の大きさである。
#
# 等速円運動の速度の大きさは
# $$v=r \omega$$
# であった。
# よって上図の半径は$r \omega$である。
# 速度は常に円の接線方向であること、この円運動では質点は一秒間に$\omega$だけ回転することを思い出せば、二つのやじるしがなす角は$\omega$である。
# したがって、二つのベクトルが切り取る弧の長さは$r\omega ^2$である。

# %% [markdown]
# $\varDelta t$が限りなく小さいならば、この弧の長さは黒い矢印の長さと同じとみなせる。
#
# つまり、加速度$\vec{a}$の大きさは
# $$a = r \omega ^2$$
# である。

# %% [markdown]
# 加速度$\vec{a}$の向きについてだが、これは速度の方向を考えたときと同様に、$\varDelta t$を小さくしたときに黒い矢印の向きがどうなるかを考えれば良い。
# すると、加速度の向きは速度に垂直な向きであることが理解できる。
# 速度は常に円の接線方向なので、加速度は常に円の中心方向を向く。

# %% [markdown]
# 以上の内容をまとめる。
#
# 半径$r$、角速度$\omega$の等速円運動の加速度は
#
# - 円の中心向き(速度に垂直な向き)に
# - 大きさ$r\omega ^2$ (時間で変化しない)
#
# なベクトルである。

# %% [markdown]
# 等速円運動の速度と加速度をベクトルで表すと次のようになる。

# %%
gen_circularanim(data1,trj=true,vel=true,accs=true)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_gBk3EDUL25.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_gBk3EDUL25.gif")

# %% [markdown]
# ## 等速円運動に必要な力
#
# 運動方程式
# $$m \vec{a} = \vec{F}$$
# は、加速度と力が同じ向きであることを主張する。
#
# 等速円運動では加速度が常に中心方向を向いている。
# したがって力も中心方向にはたらいていることになる。
# この力の詳細については立ち入らず、ただ「円の中心を向いている」という性質に注目して、この力を向心力と呼ぶ。

# %% [markdown]
# 半径$r$角速度$\omega$の等速円運動の加速度は円の中心向きに$r\omega ^2$であったので、等速円運動の中心方向の運動方程式は
# $$mr\omega ^2 = F$$
# とかける。
#
# あるいは加速度の大きさを$\frac{v^2}{r}$と書き換えて
# $$m \frac{v^2}{r} =F$$
# とかける。
