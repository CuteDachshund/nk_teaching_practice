# %%
using Plots

# %%
g = 9.8
vx0=20
ts = range(0,10,step=0.1)
ys = 1/2 * g.*ts.^2
xs = vx0.*ts
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 2 # 質点の半径
anim = Animation()
for i in 1:length(ts)
    plt=plot(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-10,100),ylims=(-10,100),yaxis=:flip,xlabel="x",ylabel="y",linewidth=2)
    frame(anim,plt)
end
gif(anim,fps=15)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_vwhEnU9Ut8.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_vwhEnU9Ut8.gif")

# %%
g = 9.8
vx0=20
ts = range(0,10,step=0.1)
ys = 1/2 * g.*ts.^2
xs = vx0.*ts
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 2 # 質点の半径
anim = Animation()
for i in 1:length(ts)
    plt=plot(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-10,100),ylims=(-10,100),yaxis=:flip,label="",linewidth=2)
    plt=plot!(xs[1:i],ys[1:i],label="",linewidth=2)
    plt=plot!(0 .+r*cos.(theta),ys[i].+r*sin.(theta),label="",linewidth=2)
    plt=plot!(xs[i] .+r*cos.(theta),0 .+r*sin.(theta),label="",linewidth=2)
    frame(anim,plt)
end
gif(anim,fps=20)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_Za7aX8NwDY.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_Za7aX8NwDY.gif")

# %%
g = 9.8
vx0=20
ts = range(0,10,step=0.1)
ys = 1/2 * g.*ts.^2
xs = vx0.*ts
vs= round.(g.*ts,digits=3)
theta = range(0,2π,step=0.01)
r = 2 # 質点の半径
anim = Animation()
plot()
for i in 1:length(ts)
    plt=plot!(xs[i] .+r*cos.(theta),ys[i].+r*sin.(theta),aspectratio=1,xlims=(-10,100),ylims=(-10,100),yaxis=:flip,label="",linewidth=1,linecolor=:blue)
    #plt=plot!(xs[1:i],ys[1:i],label="",linewidth=5)
    plt=plot!(0 .+r*cos.(theta),ys[i].+r*sin.(theta),label="",linewidth=1,linecolor=:red)
    plt=plot!(xs[i] .+r*cos.(theta),0 .+r*sin.(theta),label="",linewidth=1,linecolor=:green)
    frame(anim,plt)
end
gif(anim,fps=20)
# Out:
# ┌ Info: Saved animation to /var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_7OdcpwJCh2.gif
# └ @ Plots /Users/busseirironibarakidaigaku/.julia/packages/Plots/esM5q/src/animation.jl:156
# Plots.AnimatedGif("/var/folders/b5/z2qg52p549x8sbr6138wf9w00000gn/T/jl_7OdcpwJCh2.gif")
